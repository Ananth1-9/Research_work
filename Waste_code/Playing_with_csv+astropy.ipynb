# %%
from astropy.table import QTable
import astropy.units as u
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits


fits.info('/Users/ananthmugundhan/Documents/Research_work/Space_data/MAST-1-Both-Filters-flc-flt-drc/MAST_2025-09-20T22_49_15.869Z/HST/jenm44010_drc.fits')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 8
#       4 import matplotlib.pyplot as plt
#       5 from astropy.io import fits
# ----> 8 fits.info('/Users/ananthmugundhan/Documents/Research_work/Space_data/MAST-1-Both-Filters-flc-flt-drc/MAST_2025-09-20T22_49_15.869Z/HST/jenm44010_drc.fits')
#
# File ~/.global_py/lib/python3.13/site-packages/astropy/io/fits/convenience.py:830, in info(filename, output, **kwargs)
#     827 if "ignore_missing_end" not in kwargs:
#     828     kwargs["ignore_missing_end"] = True
# --> 830 f = fitsopen(filename, mode=mode, **kwargs)
#     831 try:
#     832     ret = f.info(output=output)
#
# File ~/.global_py/lib/python3.13/site-packages/astropy/io/fits/hdu/hdulist.py:220, in fitsopen(name, mode, memmap, save_backup, cache, lazy_load_hdus, ignore_missing_simple, use_fsspec, fsspec_kwargs, decompress_in_memory, **kwargs)
# ...

# %%
fits.getheader('/Users/ananthmugundhan/Documents/Research_work/Space_data/MAST-1-Both-Filters-flc-flt-drc/MAST_2025-09-20T22_49_15.869Z/HST/jenm44010_drc.fits', ext=1)
# Out:
# XTENSION= 'IMAGE   '           / Image extension
# BITPIX  =                  -32 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                 4220
# NAXIS2  =                 4246
# PCOUNT  =                    0 / number of parameters
# GCOUNT  =                    1 / number of groups
# INHERIT =                    T / inherit the primary header
# EXTNAME = 'SCI     '           / extension name
# EXTVER  =                    1
# BUNIT   = 'ELECTRONS/S'        / Units of science product
#
# CD1_1   = -9.0537213909310E-06
# CD1_2   = 1.05323959070716E-05
# CD2_1   = 1.05323959070716E-05
# CD2_2   = 9.05372139093102E-06
# CRVAL1  =     20.7539006882716
# CRVAL2  =    9.091507403555418
# CRPIX1  =               2110.0
# CRPIX2  =               2123.0
# CTYPE1  = 'RA---TAN'
# CTYPE2  = 'DEC--TAN'
# ORIENTAT=    49.31741494891206
# VAFACTOR=                  1.0
#               / WFC CCD CHIP IDENTIFICATION
#
# ...

# %%
dat = fits.getdata('/Users/ananthmugundhan/Documents/Research_work/Space_data/MAST-1-Both-Filters-flc-flt-drc/MAST_2025-09-20T22_49_15.869Z/HST/jenm44010_drc.fits', ext = 1)

# %%
plt.imshow(dat)
plt.colorbar()

# %%
median = np.nanmedian(dat.ravel())

# %%
std = np.nanstd(dat.ravel())

# %%
plt.imshow(dat, vmin = median - std/100000, vmax = median + std/100000)
plt.colorbar()
